# %%
"""
Audio Talent Classification Pipeline
Processes audio files directly from GitHub, extracts features, and trains a classification model
"""

import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import warnings
import requests
from io import BytesIO
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

class GitHubAudioLoader:
    """Loads audio files directly from GitHub repository"""

    def __init__(self, repo_url="https://raw.githubusercontent.com/Mugisha-isaac/ML-pipeline-summatives"):
        self.repo_url = repo_url
        self.base_url = f"{repo_url}/main"

    def get_file_list_from_github(self, directory="data/test"):
        """
        Get list of audio files from GitHub directory using API
        """
        # API URL confirmed correct based on the directory input
        api_url = f"https://api.github.com/repos/Mugisha-isaac/ML-pipeline-summatives/contents/{directory}"

        try:
            print(f"Fetching file list from: {api_url}")
            response = requests.get(api_url, timeout=30)
            response.raise_for_status()

            files_data = response.json()
            # Filter only .wav files
            wav_files = [file['name'] for file in files_data if file['name'].endswith('.wav')]
            print(f"Found {len(wav_files)} .wav files in {directory}")
            return wav_files
        except Exception as e:
            print(f"Error fetching file list from GitHub API: {e}")
            print("Please make sure the repository is public and the path is correct.")
            return []

    def load_audio_from_url(self, file_path):
        """Load audio file directly from GitHub URL"""
        url = f"{self.base_url}/{file_path}"

        try:
            response = requests.get(url, timeout=30)
            response.raise_for_status()

            # Load audio from bytes
            audio_bytes = BytesIO(response.content)
            audio, sr = librosa.load(audio_bytes, sr=22050)
            return audio, sr
        except Exception as e:
            print(f"Error loading {url}: {e}")
            return None, None


class AudioPreprocessor:
    """Handles audio preprocessing and silence removal"""

    def __init__(self, sr=22050, top_db=20):
        self.sr = sr
        self.top_db = top_db

    def remove_silence(self, audio):
        """Remove silence from audio"""
        non_silent_intervals = librosa.effects.split(audio, top_db=self.top_db)
        if len(non_silent_intervals) == 0:
            return audio
        audio_trimmed = np.concatenate([audio[start:end] for start, end in non_silent_intervals])
        return audio_trimmed

    def visualize_waveform(self, audio, sr, title="Waveform"):
        """Display waveform"""
        plt.figure(figsize=(12, 4))
        librosa.display.waveshow(audio, sr=sr)
        plt.title(title)
        plt.xlabel("Time (s)")
        plt.ylabel("Amplitude")
        plt.tight_layout()
        return plt.gcf()

    def visualize_spectrogram(self, audio, sr, title="Spectrogram"):
        """Display spectrogram"""
        plt.figure(figsize=(12, 4))
        D = librosa.amplitude_to_db(np.abs(librosa.stft(audio)), ref=np.max)
        librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='hz')
        plt.colorbar(format='%+2.0f dB')
        plt.title(title)
        plt.tight_layout()
        return plt.gcf()


class AudioAugmenter:
    """Applies audio augmentations"""

    def __init__(self, sr=22050):
        self.sr = sr

    def pitch_shift(self, audio, n_steps=2):
        """Shift pitch by n_steps semitones"""
        return librosa.effects.pitch_shift(audio, sr=self.sr, n_steps=n_steps)

    def time_stretch(self, audio, rate=1.1):
        """Stretch or compress time"""
        return librosa.effects.time_stretch(audio, rate=rate)

    def add_noise(self, audio, noise_factor=0.005):
        """Add random white noise"""
        noise = np.random.randn(len(audio))
        return audio + noise_factor * noise

    def augment_audio(self, audio, augmentations=['pitch_shift', 'time_stretch']):
        """Apply multiple augmentations"""
        augmented = []

        if 'pitch_shift' in augmentations:
            # Use random steps for more variety
            augmented.append(self.pitch_shift(audio, n_steps=np.random.randint(-2, 3)))

        if 'time_stretch' in augmentations:
            # Use random rate
            augmented.append(self.time_stretch(audio, rate=np.random.uniform(0.9, 1.1)))

        if 'add_noise' in augmentations:
            augmented.append(self.add_noise(audio))

        return augmented


class FeatureExtractor:
    """Extracts audio features using librosa"""

    def __init__(self, sr=22050, n_mfcc=13):
        self.sr = sr
        self.n_mfcc = n_mfcc

    def extract_features(self, audio):
        """Extract comprehensive audio features"""
        features = {}

        # MFCCs (Mel-frequency cepstral coefficients)
        mfccs = librosa.feature.mfcc(y=audio, sr=self.sr, n_mfcc=self.n_mfcc)
        features['mfcc_mean'] = np.mean(mfccs, axis=1)
        features['mfcc_std'] = np.std(mfccs, axis=1)

        # Spectral features
        spectral_centroids = librosa.feature.spectral_centroid(y=audio, sr=self.sr)[0]
        features['spectral_centroid_mean'] = np.mean(spectral_centroids)
        features['spectral_centroid_std'] = np.std(spectral_centroids)

        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=self.sr)[0]
        features['spectral_rolloff_mean'] = np.mean(spectral_rolloff)
        features['spectral_rolloff_std'] = np.std(spectral_rolloff)

        # Zero crossing rate
        zcr = librosa.feature.zero_crossing_rate(audio)[0]
        features['zcr_mean'] = np.mean(zcr)
        features['zcr_std'] = np.std(zcr)

        # Energy/RMS
        rms = librosa.feature.rms(y=audio)[0]
        features['rms_mean'] = np.mean(rms)
        features['rms_std'] = np.std(rms)

        # Chroma features
        chroma = librosa.feature.chroma_stft(y=audio, sr=self.sr)
        features['chroma_mean'] = np.mean(chroma)
        features['chroma_std'] = np.std(chroma)

        # Tempo
        tempo, _ = librosa.beat.beat_track(y=audio, sr=self.sr)
        features['tempo'] = tempo

        return features

    def flatten_features(self, features_dict):
        """Flatten nested feature dictionary"""
        flat_features = {}
        for key, value in features_dict.items():
            if isinstance(value, np.ndarray):
                for i, v in enumerate(value):
                    flat_features[f"{key}_{i}"] = v
            else:
                flat_features[key] = value
        return flat_features


class TalentClassificationPipeline:
    """Main pipeline for processing and feature extraction from GitHub"""

    def __init__(self, repo_url="https://raw.githubusercontent.com/Mugisha-isaac/ML-pipeline-summatives",
                 output_csv='audio_features.csv'):
        self.github_loader = GitHubAudioLoader(repo_url)
        self.output_csv = output_csv
        self.preprocessor = AudioPreprocessor()
        self.augmenter = AudioAugmenter()
        self.feature_extractor = FeatureExtractor()
        self.features_list = []

    def get_label_from_filename(self, filename):
        """
        Extract label from filename
        Based on the pattern: Ani and Kenshin are good singers, others are bad
        """
        filename_lower = filename.lower()
        # Good singers
        if 'ani' in filename_lower or 'kenshin' in filename_lower:
            return 'good'
        # Bad singers
        else:
            return 'bad'

    def process_files_from_github(self, directory="data/test", visualize_samples=3):
        """Process all audio files from GitHub repository"""
        file_list = self.github_loader.get_file_list_from_github(directory)

        if not file_list:
            print(f"No files found in {directory}. Skipping.")
            return

        print(f"\nProcessing {len(file_list)} files from GitHub: {directory}")

        for idx, filename in enumerate(file_list):
            file_path = f"{directory}/{filename}"
            print(f"\n[{idx+1}/{len(file_list)}] Processing: {filename}")

            # Load audio from GitHub
            audio, sr = self.github_loader.load_audio_from_url(file_path)
            if audio is None:
                print(f"Skipping {filename} due to loading error")
                continue

            # Remove silence
            audio_clean = self.preprocessor.remove_silence(audio)
            print(f"Audio loaded: {len(audio_clean)/sr:.2f}s (after silence removal)")

            # Visualize first few samples
            if idx < visualize_samples:
                try:
                    # Ensure the visualizations directory exists
                    os.makedirs('visualizations', exist_ok=True)

                    fig1 = self.preprocessor.visualize_waveform(audio_clean, sr, f"Waveform: {filename}")
                    plt.savefig(f"visualizations/waveform_{filename.replace('.wav', '.png')}")
                    plt.close(fig1) # Close figure to free memory

                    fig2 = self.preprocessor.visualize_spectrogram(audio_clean, sr, f"Spectrogram: {filename}")
                    plt.savefig(f"visualizations/spectrogram_{filename.replace('.wav', '.png')}")
                    plt.close(fig2) # Close figure to free memory
                    print(f"Visualizations saved")
                except Exception as e:
                    print(f"Visualization error: {e}")

            # Get label
            file_label = self.get_label_from_filename(filename)
            print(f"Label: {file_label}")

            # Extract features from original
            features = self.feature_extractor.extract_features(audio_clean)
            features_flat = self.feature_extractor.flatten_features(features)
            features_flat['filename'] = filename
            features_flat['label'] = file_label
            features_flat['augmentation'] = 'original'
            self.features_list.append(features_flat)

            # Apply augmentations
            print(f"Applying augmentations...")
            augmented_audios = self.augmenter.augment_audio(
                audio_clean,
                augmentations=['pitch_shift', 'time_stretch', 'add_noise']
            )

            for aug_idx, aug_audio in enumerate(augmented_audios):
                aug_features = self.feature_extractor.extract_features(aug_audio)
                aug_features_flat = self.feature_extractor.flatten_features(aug_features)
                aug_features_flat['filename'] = f"{filename}_aug{aug_idx}"
                aug_features_flat['label'] = file_label
                aug_features_flat['augmentation'] = f'aug_{aug_idx}'
                self.features_list.append(aug_features_flat)

            print(f"Completed: 1 original + {len(augmented_audios)} augmentations")

    def save_features(self):
        """Save extracted features to CSV"""
        df = pd.DataFrame(self.features_list)
        df.to_csv(self.output_csv, index=False)
        print(f"\n{'='*60}")
        print(f"Features saved to {self.output_csv}")
        print(f"Total samples (including augmentations): {len(df)}")
        print(f"\nLabel distribution:")
        # Only try to show value_counts if the 'label' column exists (i.e., df is not empty)
        if 'label' in df.columns:
            print(df['label'].value_counts())
        else:
            print("No labels to display (DataFrame is empty).")
        print(f"{'='*60}")
        return df


class TalentClassifier:
    """Deep learning model for talent classification"""

    def __init__(self, input_dim):
        self.input_dim = input_dim
        self.model = None
        self.scaler = StandardScaler()
        self.label_encoder = LabelEncoder()
        self.history = None

    def build_model(self):
        """Build deep neural network"""
        model = keras.Sequential([
            layers.Dense(256, activation='relu', input_shape=(self.input_dim,)),
            layers.Dropout(0.3),
            layers.BatchNormalization(),

            layers.Dense(128, activation='relu'),
            layers.Dropout(0.3),
            layers.BatchNormalization(),

            layers.Dense(64, activation='relu'),
            layers.Dropout(0.2),
            layers.BatchNormalization(),

            layers.Dense(32, activation='relu'),
            layers.Dropout(0.2),

            layers.Dense(1, activation='sigmoid')
        ])

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=0.001),
            loss='binary_crossentropy',
            metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall()]
        )

        self.model = model
        return model

    def prepare_data(self, df):
        """Prepare data for training"""
        # Remove non-feature columns
        feature_cols = [col for col in df.columns if col not in ['filename', 'label', 'augmentation']]
        X = df[feature_cols].values
        y = df['label'].values

        # Encode labels
        y_encoded = self.label_encoder.fit_transform(y)

        # Split data
        X_train, X_test, y_train, y_test = train_test_split(
            X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
        )

        # Scale features
        X_train_scaled = self.scaler.fit_transform(X_train)
        X_test_scaled = self.scaler.transform(X_test)

        return X_train_scaled, X_test_scaled, y_train, y_test

    def train(self, X_train, y_train, X_test, y_test, epochs=100, batch_size=32):
        """Train the model"""
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True
        )

        reduce_lr = keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=0.00001
        )

        self.history = self.model.fit(
            X_train, y_train,
            validation_data=(X_test, y_test),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        return self.history

    def evaluate(self, X_test, y_test):
        """Evaluate model performance and display a metrics table"""
        y_pred_prob = self.model.predict(X_test, verbose=0)
        y_pred = (y_pred_prob > 0.5).astype(int).flatten()

        # Calculate primary metrics (5 metrics used)
        acc = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        # Get final test loss from model evaluation
        loss = self.model.evaluate(X_test, y_test, verbose=0)[0]

        # Create metrics DataFrame (The requested metrics table)
        metrics = {
            'Metric': ['Accuracy', 'Loss', 'Precision', 'Recall', 'F1-Score'],
            'Value': [
                f"{acc:.4f}",
                f"{loss:.4f}",
                f"{precision:.4f}",
                f"{recall:.4f}",
                f"{f1:.4f}"
            ]
        }
        metrics_df = pd.DataFrame(metrics)

        print("\n" + "="*60)
        print("MODEL EVALUATION RESULTS")
        print("="*60)

        print("\nClassification Report:")
        print(classification_report(y_test, y_pred, target_names=self.label_encoder.classes_))

        print("\n" + "-"*60)
        print("MODEL METRICS TABLE")
        # Display the table in Markdown format
        print(metrics_df.to_markdown(index=False))
        print("-"*60)

        print("="*60)

        return y_pred, y_pred_prob

    def plot_training_history(self):
        """Plot training metrics"""
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))

        # Accuracy
        axes[0, 0].plot(self.history.history['accuracy'], label='Train Accuracy')
        axes[0, 0].plot(self.history.history['val_accuracy'], label='Val Accuracy')
        axes[0, 0].set_title('Model Accuracy')
        axes[0, 0].set_xlabel('Epoch')
        axes[0, 0].set_ylabel('Accuracy')
        axes[0, 0].legend()
        axes[0, 0].grid(True)

        # Loss
        axes[0, 1].plot(self.history.history['loss'], label='Train Loss')
        axes[0, 1].plot(self.history.history['val_loss'], label='Val Loss')
        axes[0, 1].set_title('Model Loss')
        axes[0, 1].set_xlabel('Epoch')
        axes[0, 1].set_ylabel('Loss')
        axes[0, 1].legend()
        axes[0, 1].grid(True)

        # Precision
        axes[1, 0].plot(self.history.history['precision'], label='Train Precision')
        axes[1, 0].plot(self.history.history['val_precision'], label='Val Precision')
        axes[1, 0].set_title('Model Precision')
        axes[1, 0].set_xlabel('Epoch')
        axes[1, 0].set_ylabel('Precision')
        axes[1, 0].legend()
        axes[1, 0].grid(True)

        # Recall
        axes[1, 1].plot(self.history.history['recall'], label='Train Recall')
        axes[1, 1].plot(self.history.history['val_recall'], label='Val Recall')
        axes[1, 1].set_title('Model Recall')
        axes[1, 1].set_xlabel('Epoch')
        axes[1, 1].set_ylabel('Recall')
        axes[1, 1].legend()
        axes[1, 1].grid(True)

        plt.tight_layout()
        plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
        print("Training history plot saved to 'training_history.png'")

    def plot_confusion_matrix(self, y_test, y_pred):
        """Plot confusion matrix"""
        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=self.label_encoder.classes_,
                    yticklabels=self.label_encoder.classes_)
        plt.title('Confusion Matrix')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
        print("Confusion matrix saved to 'confusion_matrix.png'")

    def save_model(self, model_path='talent_classifier_model.h5'):
        """Save trained model"""
        self.model.save(model_path)
        print(f"\nModel saved to {model_path}")

        # Save scaler and label encoder
        import pickle
        with open('scaler.pkl', 'wb') as f:
            pickle.dump(self.scaler, f)
        with open('label_encoder.pkl', 'wb') as f:
            pickle.dump(self.label_encoder, f)
        print("Scaler and label encoder saved")


# Main execution
if __name__ == "__main__":
    # Create output directories
    os.makedirs('visualizations', exist_ok=True)

    print("="*60)
    print("AUDIO TALENT CLASSIFICATION PIPELINE")
    print("Loading data from GitHub repository")
    print("="*60)

    # Step 1: Process audio files and extract features
    print("\n[STEP 1] Processing audio files and extracting features...")
    pipeline = TalentClassificationPipeline(
        repo_url="https://raw.githubusercontent.com/Mugisha-isaac/ML-pipeline-summatives"
    )

    # --- FIX APPLIED HERE: UPDATING PATHS TO NEW GITHUB STRUCTURE ---
    # New path is 'backend/data/train' and 'backend/data/test'
    print("\n>>> Processing TRAINING data from GitHub...")
    pipeline.process_files_from_github('backend/data/train', visualize_samples=2)

    print("\n>>> Processing TEST data from GitHub...")
    pipeline.process_files_from_github('backend/data/test', visualize_samples=2)
    # ----------------------------------------------------------------

    # Save features
    df_features = pipeline.save_features()

    # --- FIX APPLIED HERE: GRACEFULLY HANDLE EMPTY DATAFRAME ---
    if len(df_features) == 0:
        print("\n" + "="*60)
        print("🚨 CRITICAL ERROR: NO FEATURES EXTRACTED. MODEL TRAINING SKIPPED.")
        print("Please check the GitHub repository link and ensure files are present.")
        print("="*60)
    else:
        # Step 2: Train the model
        print("\n" + "="*60)
        print("[STEP 2] Training classification model...")
        print("="*60)
        # -3 accounts for 'filename', 'label', 'augmentation' columns
        classifier = TalentClassifier(input_dim=df_features.shape[1] - 3)
        classifier.build_model()

        print("\nModel Architecture:")
        classifier.model.summary()

        # Prepare data
        X_train, X_test, y_train, y_test = classifier.prepare_data(df_features)
        print(f"\nTraining samples: {len(X_train)}")
        print(f"Test samples: {len(X_test)}")

        # Train
        print("\nTraining model...")
        classifier.train(X_train, y_train, X_test, y_test, epochs=100, batch_size=32)

        # Step 3: Evaluate and visualize
        print("\n" + "="*60)
        print("[STEP 3] Evaluating model and generating metrics table...")
        print("="*60)
        # Calls the updated method which prints the metrics table
        y_pred, y_pred_prob = classifier.evaluate(X_test, y_test)

        # Plot results
        print("\nGenerating visualizations...")
        try:
            classifier.plot_training_history()
            classifier.plot_confusion_matrix(y_test, y_pred)
        except Exception as e:
            print(f"Could not generate plots. Error: {e}")


        # Step 4: Save model
        print("\n" + "="*60)
        print("[STEP 4] Saving model...")
        print("="*60)
        try:
            classifier.save_model('talent_classifier_model.h5')
        except Exception as e:
            print(f"Could not save model artifacts. Error: {e}")

    # -------------------------------------------------------------

    print("\n" + "="*60)
    print("PIPELINE COMPLETE!")
    print("="*60)
    print("\nOutput files created:")
    print("[DONE] audio_features.csv - Extracted features dataset")
    print("[DONE] talent_classifier_model.h5 - Trained model (if successful)")
    print("[DONE] scaler.pkl - Feature scaler (if successful)")
    print("[DONE] label_encoder.pkl - Label encoder (if successful)")
    print("[DONE] training_history.png - Training metrics visualization (if successful)")
    print("[DONE] confusion_matrix.png - Model performance matrix (if successful)")
    print("[DONE] visualizations/ - Sample waveforms and spectrograms")
    print("\nNow, the pipeline should successfully fetch data from the updated GitHub location!")
    print("="*60)
# Out:
# Streaming output truncated to the last 5000 lines.
# Completed: 1 original + 3 augmentations
#
# [282/1000] Processing: annar_3_01.wav
# Audio loaded: 6.27s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [283/1000] Processing: annar_3_02.wav
# Audio loaded: 5.95s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [284/1000] Processing: annar_3_03.wav
# Audio loaded: 5.86s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [285/1000] Processing: annar_3_04.wav
# Audio loaded: 5.86s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [286/1000] Processing: annar_3_05.wav
# Audio loaded: 5.31s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [287/1000] Processing: annar_3_06.wav
# Audio loaded: 6.37s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [288/1000] Processing: annar_3_07.wav
# Audio loaded: 5.28s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [289/1000] Processing: annar_3_08.wav
# Audio loaded: 5.23s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [290/1000] Processing: annar_4_01.wav
# Audio loaded: 7.39s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [291/1000] Processing: annar_4_02.wav
# Audio loaded: 5.12s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [292/1000] Processing: annar_4_03.wav
# Audio loaded: 9.70s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [293/1000] Processing: annar_4_04.wav
# Audio loaded: 5.97s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [294/1000] Processing: annar_4_05.wav
# Audio loaded: 5.22s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [295/1000] Processing: annar_4_06.wav
# Audio loaded: 9.38s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [296/1000] Processing: annar_4_07.wav
# Audio loaded: 5.56s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [297/1000] Processing: annar_4_08.wav
# Audio loaded: 5.31s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [298/1000] Processing: annar_4_09.wav
# Audio loaded: 9.86s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [299/1000] Processing: annar_5_01.wav
# Audio loaded: 5.38s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [300/1000] Processing: annar_5_02.wav
# Audio loaded: 6.62s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [301/1000] Processing: annar_5_03.wav
# Audio loaded: 5.95s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [302/1000] Processing: annar_5_04.wav
# Audio loaded: 9.50s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [303/1000] Processing: annar_5_05.wav
# Audio loaded: 5.54s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [304/1000] Processing: annar_5_06.wav
# Audio loaded: 9.57s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [305/1000] Processing: annar_5_07.wav
# Audio loaded: 6.34s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [306/1000] Processing: annar_5_08.wav
# Audio loaded: 6.46s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [307/1000] Processing: annar_5_09.wav
# Audio loaded: 6.72s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [308/1000] Processing: ariel_1_01.wav
# Audio loaded: 9.22s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [309/1000] Processing: ariel_1_02.wav
# Audio loaded: 9.55s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [310/1000] Processing: ariel_1_03.wav
# Audio loaded: 9.89s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
#
(after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [568/1000] Processing: geniusturtle_4_10.wav
# Audio loaded: 6.24s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [569/1000] Processing: geniusturtle_4_11.wav
# Audio loaded: 8.22s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [570/1000] Processing: geniusturtle_4_12.wav
# Audio loaded: 7.21s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [571/1000] Processing: geniusturtle_5_01.wav
# Audio loaded: 10.88s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [572/1000] Processing: geniusturtle_5_02.wav
# Audio loaded: 10.94s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [573/1000] Processing: geniusturtle_5_03.wav
# Audio loaded: 10.69s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [574/1000] Processing: geniusturtle_5_04.wav
# Audio loaded: 11.27s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [575/1000] Processing: geniusturtle_6_01.wav
# Audio loaded: 10.34s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [576/1000] Processing: geniusturtle_6_02.wav
# Audio loaded: 10.18s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [577/1000] Processing: geniusturtle_6_03.wav
# Audio loaded: 10.24s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# [578/1000] Processing: geniusturtle_6_04.wav
# Audio loaded: 9.63s (after silence removal)
# Label: bad
# Applying augmentations...
# Completed: 1 original + 3 augmentations
#
# ...
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,785 (214.00 KB)
#  Trainable params: 53,889 (210.50 KB)
#  Non-trainable params: 896 (3.50 KB)
# Training samples: 3552
# Test samples: 888
#
# Training model...
# Epoch 1/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8106 - loss: 0.4503 - precision: 0.1258 - recall: 0.1807 - val_accuracy: 0.9155 - val_loss: 0.2702 - val_precision: 1.0000 - val_recall: 0.0625 - learning_rate: 0.0010
# Epoch 2/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.2578 - precision: 0.5050 - recall: 0.1408 - val_accuracy: 0.9291 - val_loss: 0.1966 - val_precision: 0.9048 - val_recall: 0.2375 - learning_rate: 0.0010
# Epoch 3/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9195 - loss: 0.2164 - precision: 0.5516 - recall: 0.2884 - val_accuracy: 0.9392 - val_loss: 0.1750 - val_precision: 0.8421 - val_recall: 0.4000 - learning_rate: 0.0010
# Epoch 4/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9309 - loss: 0.2021 - precision: 0.6731 - recall: 0.3613 - val_accuracy: 0.9448 - val_loss: 0.1545 - val_precision: 0.8298 - val_recall: 0.4875 - learning_rate: 0.0010
# Epoch 5/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9355 - loss: 0.1763 - precision: 0.6948 - recall: 0.4390 - val_accuracy: 0.9459 - val_loss: 0.1449 - val_precision: 0.8333 - val_recall: 0.5000 - learning_rate: 0.0010
# Epoch 6/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9416 - loss: 0.1673 - precision: 0.7537 - recall: 0.4603 - val_accuracy: 0.9527 - val_loss: 0.1331 - val_precision: 0.8393 - val_recall: 0.5875 - learning_rate: 0.0010
# Epoch 7/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1541 - precision: 0.7244 - recall: 0.4909 - val_accuracy: 0.9516 - val_loss: 0.1175 - val_precision: 0.8033 - val_recall: 0.6125 - learning_rate: 0.0010
# Epoch 8/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9376 - loss: 0.1532 - precision: 0.6715 - recall: 0.5162 - val_accuracy: 0.9505 - val_loss: 0.1112 - val_precision: 0.8214 - val_recall: 0.5750 - learning_rate: 0.0010
# Epoch 9/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9540 - loss: 0.1299 - precision: 0.7643 - recall: 0.6636 - val_accuracy: 0.9628 - val_loss: 0.0971 - val_precision: 0.8507 - val_recall: 0.7125 - learning_rate: 0.0010
# Epoch 10/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.1165 - precision: 0.8436 - recall: 0.6590 - val_accuracy: 0.9606 - val_loss: 0.0897 - val_precision: 0.8169 - val_recall: 0.7250 - learning_rate: 0.0010
# Epoch 11/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1125 - precision: 0.7919 - recall: 0.6550 - val_accuracy: 0.9640 - val_loss: 0.0927 - val_precision: 0.8243 - val_recall: 0.7625 - learning_rate: 0.0010
# Epoch 12/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.1054 - precision: 0.7600 - recall: 0.6862 - val_accuracy: 0.9640 - val_loss: 0.0886 - val_precision: 0.8243 - val_recall: 0.7625 - learning_rate: 0.0010
# Epoch 13/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9591 - loss: 0.1067 - precision: 0.7863 - recall: 0.7120 - val_accuracy: 0.9696 - val_loss: 0.0841 - val_precision: 0.8841 - val_recall: 0.7625 - learning_rate: 0.0010
# Epoch 14/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9703 - loss: 0.0884 - precision: 0.8797 - recall: 0.7586 - val_accuracy: 0.9718 - val_loss: 0.0741 - val_precision: 0.9365 - val_recall: 0.7375 - learning_rate: 0.0010
# Epoch 15/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9639 - loss: 0.0929 - precision: 0.8077 - recall: 0.7536 - val_accuracy: 0.9775 - val_loss: 0.0596 - val_precision: 0.9054 - val_recall: 0.8375 - learning_rate: 0.0010
# Epoch 16/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9721 - loss: 0.0815 - precision: 0.8711 - recall: 0.7912 - val_accuracy: 0.9764 - val_loss: 0.0681 - val_precision: 0.9041 - val_recall: 0.8250 - learning_rate: 0.0010
# Epoch 17/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.0800 - precision: 0.8326 - recall: 0.7912 - val_accuracy: 0.9775 - val_loss: 0.0688 - val_precision: 0.8947 - val_recall: 0.8500 - learning_rate: 0.0010
# Epoch 18/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.0746 - precision: 0.8807 - recall: 0.7777 - val_accuracy: 0.9809 - val_loss: 0.0595 - val_precision: 0.9091 - val_recall: 0.8750 - learning_rate: 0.0010
# Epoch 19/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9726 - loss: 0.0679 - precision: 0.8411 - recall: 0.8383 - val_accuracy: 0.9696 - val_loss: 0.0813 - val_precision: 0.8193 - val_recall: 0.8500 - learning_rate: 0.0010
# Epoch 20/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9758 - loss: 0.0694 - precision: 0.8791 - recall: 0.8314 - val_accuracy: 0.9730 - val_loss: 0.0661 - val_precision: 0.8590 - val_recall: 0.8375 - learning_rate: 0.0010
# Epoch 21/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.0559 - precision: 0.8646 - recall: 0.8418 - val_accuracy: 0.9662 - val_loss: 0.0687 - val_precision: 0.8205 - val_recall: 0.8000 - learning_rate: 0.0010
# Epoch 22/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9684 - loss: 0.0688 - precision: 0.8084 - recall: 0.8217 - val_accuracy: 0.9797 - val_loss: 0.0723 - val_precision: 0.9429 - val_recall: 0.8250 - learning_rate: 0.0010
# Epoch 23/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9765 - loss: 0.0761 - precision: 0.8819 - recall: 0.8398 - val_accuracy: 0.9752 - val_loss: 0.0647 - val_precision: 0.8625 - val_recall: 0.8625 - learning_rate: 0.0010
# Epoch 24/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9797 - loss: 0.0545 - precision: 0.8687 - recall: 0.8967 - val_accuracy: 0.9831 - val_loss: 0.0605 - val_precision: 0.9221 - val_recall: 0.8875 - learning_rate: 5.0000e-04
# Epoch 25/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0426 - precision: 0.9104 - recall: 0.8910 - val_accuracy: 0.9854 - val_loss: 0.0584 - val_precision: 0.9467 - val_recall: 0.8875 - learning_rate: 5.0000e-04
# Epoch 26/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0439 - precision: 0.9104 - recall: 0.9101 - val_accuracy: 0.9842 - val_loss: 0.0586 - val_precision: 0.9342 - val_recall: 0.8875 - learning_rate: 5.0000e-04
# Epoch 27/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9853 - loss: 0.0408 - precision: 0.9338 - recall: 0.8923 - val_accuracy: 0.9831 - val_loss: 0.0604 - val_precision: 0.9577 - val_recall: 0.8500 - learning_rate: 5.0000e-04
# Epoch 28/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9896 - loss: 0.0315 - precision: 0.9493 - recall: 0.9293 - val_accuracy: 0.9820 - val_loss: 0.0633 - val_precision: 0.9444 - val_recall: 0.8500 - learning_rate: 5.0000e-04
# Epoch 29/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9870 - loss: 0.0355 - precision: 0.9428 - recall: 0.9019 - val_accuracy: 0.9842 - val_loss: 0.0535 - val_precision: 0.9342 - val_recall: 0.8875 - learning_rate: 5.0000e-04
# Epoch 30/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9868 - loss: 0.0392 - precision: 0.9225 - recall: 0.9238 - val_accuracy: 0.9831 - val_loss: 0.0557 - val_precision: 0.9333 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 31/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0292 - precision: 0.9422 - recall: 0.9594 - val_accuracy: 0.9854 - val_loss: 0.0560 - val_precision: 0.9467 - val_recall: 0.8875 - learning_rate: 5.0000e-04
# Epoch 32/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0298 - precision: 0.9243 - recall: 0.9473 - val_accuracy: 0.9865 - val_loss: 0.0492 - val_precision: 0.9359 - val_recall: 0.9125 - learning_rate: 5.0000e-04
# Epoch 33/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0264 - precision: 0.9398 - recall: 0.9500 - val_accuracy: 0.9809 - val_loss: 0.0670 - val_precision: 0.9315 - val_recall: 0.8500 - learning_rate: 5.0000e-04
# Epoch 34/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0311 - precision: 0.9332 - recall: 0.9585 - val_accuracy: 0.9854 - val_loss: 0.0560 - val_precision: 0.9351 - val_recall: 0.9000 - learning_rate: 5.0000e-04
# Epoch 35/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9909 - loss: 0.0254 - precision: 0.9488 - recall: 0.9438 - val_accuracy: 0.9842 - val_loss: 0.0540 - val_precision: 0.9231 - val_recall: 0.9000 - learning_rate: 5.0000e-04
# Epoch 36/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0288 - precision: 0.9442 - recall: 0.9413 - val_accuracy: 0.9842 - val_loss: 0.0583 - val_precision: 0.9125 - val_recall: 0.9125 - learning_rate: 5.0000e-04
# Epoch 37/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9845 - loss: 0.0410 - precision: 0.8872 - recall: 0.9312 - val_accuracy: 0.9831 - val_loss: 0.0594 - val_precision: 0.9114 - val_recall: 0.9000 - learning_rate: 5.0000e-04
# Epoch 38/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9923 - loss: 0.0222 - precision: 0.9347 - recall: 0.9792 - val_accuracy: 0.9854 - val_loss: 0.0610 - val_precision: 0.9467 - val_recall: 0.8875 - learning_rate: 2.5000e-04
# Epoch 39/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9933 - loss: 0.0246 - precision: 0.9682 - recall: 0.9539 - val_accuracy: 0.9854 - val_loss: 0.0642 - val_precision: 0.9351 - val_recall: 0.9000 - learning_rate: 2.5000e-04
# Epoch 40/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9949 - loss: 0.0178 - precision: 0.9604 - recall: 0.9819 - val_accuracy: 0.9831 - val_loss: 0.0614 - val_precision: 0.9333 - val_recall: 0.8750 - learning_rate: 2.5000e-04
# Epoch 41/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0238 - precision: 0.9547 - recall: 0.9490 - val_accuracy: 0.9842 - val_loss: 0.0596 - val_precision: 0.9231 - val_recall: 0.9000 - learning_rate: 2.5000e-04
# Epoch 42/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9898 - loss: 0.0251 - precision: 0.9379 - recall: 0.9429 - val_accuracy: 0.9831 - val_loss: 0.0664 - val_precision: 0.9333 - val_recall: 0.8750 - learning_rate: 2.5000e-04
# Epoch 43/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9931 - loss: 0.0204 - precision: 0.9606 - recall: 0.9592 - val_accuracy: 0.9831 - val_loss: 0.0673 - val_precision: 0.9452 - val_recall: 0.8625 - learning_rate: 1.2500e-04
# Epoch 44/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0199 - precision: 0.9571 - recall: 0.9595 - val_accuracy: 0.9842 - val_loss: 0.0623 - val_precision: 0.9342 - val_recall: 0.8875 - learning_rate: 1.2500e-04
# Epoch 45/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9933 - loss: 0.0186 - precision: 0.9500 - recall: 0.9734 - val_accuracy: 0.9831 - val_loss: 0.0626 - val_precision: 0.9221 - val_recall: 0.8875 - learning_rate: 1.2500e-04
# Epoch 46/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0202 - precision: 0.9574 - recall: 0.9631 - val_accuracy: 0.9842 - val_loss: 0.0617 - val_precision: 0.9342 - val_recall: 0.8875 - learning_rate: 1.2500e-04
# Epoch 47/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0209 - precision: 0.9503 - recall: 0.9740 - val_accuracy: 0.9854 - val_loss: 0.0611 - val_precision: 0.9467 - val_recall: 0.8875 - learning_rate: 1.2500e-04
#
# ============================================================
# [STEP 3] Evaluating model and generating metrics table...
# ============================================================
#
# ============================================================
# MODEL EVALUATION RESULTS
# ============================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          bad       0.99      0.99      0.99       808
#         good       0.94      0.91      0.92        80
#
#     accuracy                           0.99       888
#    macro avg       0.96      0.95      0.96       888
# weighted avg       0.99      0.99      0.99       888
#
#
# ------------------------------------------------------------
# MODEL METRICS TABLE
# | Metric    |   Value |
# |:----------|--------:|
# | Accuracy  |  0.9865 |
# | Loss      |  0.0492 |
# | Precision |  0.9359 |
# | Recall    |  0.9125 |
# | F1-Score  |  0.9241 |
# ------------------------------------------------------------
# ============================================================
#
# Generating visualizations...
# Training history plot saved to 'training_history.png'
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Confusion matrix saved to 'confusion_matrix.png'
#
# ============================================================
# [STEP 4] Saving model...
# ============================================================
#
# Model saved to talent_classifier_model.h5
# Scaler and label encoder saved
#
# ============================================================
# PIPELINE COMPLETE!
# ============================================================
#
# Output files created:
# [DONE] audio_features.csv - Extracted features dataset
# [DONE] talent_classifier_model.h5 - Trained model (if successful)
# [DONE] scaler.pkl - Feature scaler (if successful)
# [DONE] label_encoder.pkl - Label encoder (if successful)
# [DONE] training_history.png - Training metrics visualization (if successful)
# [DONE] confusion_matrix.png - Model performance matrix (if successful)
# [DONE] visualizations/ - Sample waveforms and spectrograms
#
# Now, the pipeline should successfully fetch data from the updated GitHub location!
# ============================================================
